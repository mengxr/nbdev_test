# %%
# %load_ext autoreload
# Out:
# <pre class="jp-command-status-text">Command took 0.10 seconds -- by meng@databricks.com at 02/06/2020, 10:58:17 PM UTC on Jupyter</pre>
# Accordion(children=(VBox(),), layout=Layout(display='none'), selected_index=None)
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2
# Out:
# <pre class="jp-command-status-text">Command took 0.02 seconds -- by meng@databricks.com at 02/06/2020, 10:58:18 PM UTC on Jupyter</pre>
# Accordion(children=(VBox(),), layout=Layout(display='none'), selected_index=None)

# %%
from nbdev_test.core import test
# Out:
# <pre class="jp-command-status-text">Command took 0.02 seconds -- by meng@databricks.com at 02/06/2020, 10:58:18 PM UTC on Jupyter</pre>
# Accordion(children=(VBox(),), layout=Layout(display='none'), selected_index=None)

# %%
test()
# Out:
# <pre class="jp-command-status-text">Command took 0.02 seconds -- by meng@databricks.com at 02/06/2020, 10:58:22 PM UTC on Jupyter</pre>
# Accordion(children=(VBox(),), layout=Layout(display='none'), selected_index=None)
# test

# %%
from nbdev_test.util import third_test
# Out:
# <pre class="jp-command-status-text">Command took 0.14 seconds -- by meng@databricks.com at 02/06/2020, 10:59:47 PM UTC on Jupyter</pre>
# Accordion(children=(VBox(),), layout=Layout(display='none'), selected_index=None)

# %%
third_test()
# Out:
# <pre class="jp-command-status-text">Command took 0.02 seconds -- by meng@databricks.com at 02/06/2020, 10:59:58 PM UTC on Jupyter</pre>
# Accordion(children=(VBox(),), layout=Layout(display='none'), selected_index=None)
# test

# %%
from nbdev.export import *
notebook2script()
# Out:
# <pre class="jp-command-status-text">Command took 0.79 seconds -- by meng@databricks.com at 02/06/2020, 10:59:36 PM UTC on Jupyter</pre>
# Accordion(children=(VBox(),), layout=Layout(display='none'), selected_index=None)
# Converted 00_core.ipynb.
# Converted 01_util.ipynb.
# Converted index.ipynb.
# Converted test.ipynb.
