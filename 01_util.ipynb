# %%
#default_exp util

# %% [markdown]
# # Util module

# %%
#export
from nbdev_test.core import test

# %%
#export
def another_test():
    test()

# %%
another_test()
# Out:
# test

# %%
#export
def _private():
    pass

# %%
#export
def third_test():
    another_test()
# Out:
# <pre class="jp-command-status-text">Command execution completed</pre>
# Accordion(children=(VBox(),), layout=Layout(display='none'), selected_index=None)
